# %% [markdown]
# <a href="https://colab.research.google.com/github/saiteja-1919/mart-To-Do-List-Application/blob/main/To_Do_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = """
<!DOCTYPE html>
<html>
<body>
<h2>To Do List</h2>
<input id="task">
<button onclick="add()">Add</button>
<ul id="list"></ul>

<script>
function add(){
  let task = document.getElementById("task").value;
  let li = document.createElement("li");
  li.innerText = task;
  li.onclick = () => li.remove();
  document.getElementById("list").appendChild(li);
}
</script>
</body>
</html>
"""
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html>
# <body>
# <h2>To Do List</h2>
# <input id="task">
# <button onclick="add()">Add</button>
# <ul id="list"></ul>
#
# <script>
# function add(){
#   let task = document.getElementById("task").value;
#   let li = document.createElement("li");
#   li.innerText = task;
#   li.onclick = () => li.remove();
#   document.getElementById("list").appendChild(li);
# }
# </script>
# </body>
# </html>
